# %%
import pandas as pd

# %%
placement = pd.read_csv('data/AMSPlacement.csv')
placement_detail = pd.read_csv('data/AMSPlacementDetail.csv')

# %%
placement = placement.rename(columns= {"campaign": "campaign1", "placement": "placement_type"})
placement_detail = placement_detail.join(placement.set_index('id'), on = 'placement')

# %%
placement_detail.T
# Out:
#                                 0              1              2     \
# id                                 1              2              3
# placement                       5698           5698           5698
# date                        10/13/19       10/14/19       10/15/19
# impressions                      149            145            129
# clicks                             3              4              3
# CtR                         0.020134       0.027586       0.023256
# CpC                             0.35           0.58            0.6
# spend                           1.05           2.31            1.8
# ACoS                        0.015996       0.077154       0.276074
# RoAS                          0.6251         0.1296         0.0362
# sales                          65.64          29.94           6.52
# orders                             3              1              1
# units                              6              1              1
# conversion_rate                    1           0.25       0.333333
# page_views                         8             12             21
# NtB_orders                         0              0              0
# NtB_orders_percentage              0              0              0
# NtB_sales                          0              0              0
# NtB_sales_percentage               0              0              0
# NtB_units                          0              0              0
# NtB_units_persentage               0              0              0
# NtB_order_rate                     0              0              0
# campaign1                         93             93             93
# placement_type         Top of Search  Top of Search  Top of Search
#
#                                 3              4              5     \
# id                                 4              5              6
# placement                       5698           5698           5698
# date                        10/16/19       10/17/19       10/18/19
# impressions                      121             88            100
# clicks                             3              5              3
# CtR                         0.024793       0.056818           0.03
# CpC                              0.7           0.53           1.58
# spend                            2.1           2.66           4.74
# ACoS                        0.060276        0.13634            NaN
# RoAS                          0.1659         0.0733              0
# sales                          34.84          19.51              0
# orders                             2              1              0
# units                              2              1              0
# conversion_rate             0.666667            0.2              0
# page_views                         4              6             21
# NtB_orders                         2              1              0
# NtB_orders_percentage              1              1            NaN
# NtB_sales                      34.84          19.51              0
# NtB_sales_percentage               1              1            NaN
# NtB_units                          2              1              0
# NtB_units_persentage               1              1            NaN
# NtB_order_rate              0.666667            0.2              0
# campaign1                         93             93             93
# placement_type         Top of Search  Top of Search  Top of Search
#
#                                 6              7              8     \
# id                                 7              8              9
# placement                       5698           5705           5705
# date                        10/19/19       10/13/19       10/14/19
# impressions                      129           1765           1372
# clicks                             6              6             13
# CtR                         0.046512       0.003399       0.009475
# CpC                             0.67           0.52           0.51
# spend                           4.01           3.09           6.61
# ACoS                        0.065363            NaN       0.144829
# RoAS                           0.153              0          0.069
# sales                          61.35              0          45.64
# orders                             2              0              1
# units                              3              0              2
# conversion_rate             0.333333              0       0.076923
# page_views                         3              3             12
# NtB_orders                         1              0              1
# NtB_orders_percentage            0.5            NaN              1
# NtB_sales                      20.45              0          45.64
# NtB_sales_percentage        0.333333            NaN              1
# NtB_units                          1              0              2
# NtB_units_persentage        0.333333            NaN              1
# NtB_order_rate              0.166667              0       0.076923
# campaign1                         93            100            100
# placement_type         Top of Search  Top of Search  Top of Search
#
#                                 9     ...                      5837  \
# id                                10  ...                      5840
# placement                       5705  ...                     31229
# date                        10/15/19  ...                   10/1/19
# impressions                      772  ...                        69
# clicks                            13  ...                         0
# CtR                         0.016839  ...                       NaN
# CpC                             0.51  ...                       NaN
# spend                           6.63  ...                         0
# ACoS                        0.167424  ...                       NaN
# RoAS                          0.0597  ...                       NaN
# sales                           39.6  ...                         0
# orders                             1  ...                         0
# units                              1  ...                         0
# conversion_rate             0.076923  ...                       NaN
# page_views                        15  ...                       NaN
# NtB_orders                         0  ...                       NaN
# NtB_orders_percentage              0  ...                       NaN
# NtB_sales                          0  ...                       NaN
# NtB_sales_percentage               0  ...                       NaN
# NtB_units                          0  ...                       NaN
# NtB_units_persentage               0  ...                       NaN
# NtB_order_rate                     0  ...                       NaN
# campaign1                        100  ...                      1234
# placement_type         Top of Search  ...  Rest of search on Amazon
#
#                                            5838                      5839  \
# id                                         5841                      5842
# placement                                 31229                     31229
# date                                    10/2/19                   10/3/19
# impressions                                  64                        71
# clicks                                        1                         0
# CtR                                         NaN                       NaN
# CpC                                        0.41                       NaN
# spend                                      0.41                         0
# ACoS                                        NaN                       NaN
# RoAS                                          0                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1234                      1234
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5840                      5841  \
# id                                         5843                      5844
# placement                                 31229                     31229
# date                                    10/4/19                   10/5/19
# impressions                                  56                        63
# clicks                                        0                         0
# CtR                                         NaN                       NaN
# CpC                                         NaN                       NaN
# spend                                         0                         0
# ACoS                                        NaN                       NaN
# RoAS                                        NaN                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1234                      1234
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5842                      5843  \
# id                                         5845                      5846
# placement                                 31235                     31235
# date                                    9/29/19                   9/30/19
# impressions                                 143                        90
# clicks                                        2                         0
# CtR                                         NaN                       NaN
# CpC                                        0.46                       NaN
# spend                                      0.92                         0
# ACoS                                        NaN                       NaN
# RoAS                                          0                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1226                      1226
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5844                      5845  \
# id                                         5847                      5848
# placement                                 31235                     31235
# date                                    10/1/19                   10/2/19
# impressions                                  39                        54
# clicks                                        0                         0
# CtR                                         NaN                       NaN
# CpC                                         NaN                       NaN
# spend                                         0                         0
# ACoS                                        NaN                       NaN
# RoAS                                        NaN                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1226                      1226
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5846
# id                                         5849
# placement                                 31235
# date                                    10/3/19
# impressions                                  52
# clicks                                        0
# CtR                                         NaN
# CpC                                         NaN
# spend                                         0
# ACoS                                        NaN
# RoAS                                        NaN
# sales                                         0
# orders                                        0
# units                                         0
# conversion_rate                             NaN
# page_views                                  NaN
# NtB_orders                                  NaN
# NtB_orders_percentage                       NaN
# NtB_sales                                   NaN
# NtB_sales_percentage                        NaN
# NtB_units                                   NaN
# NtB_units_persentage                        NaN
# NtB_order_rate                              NaN
# campaign1                                  1226
# placement_type         Rest of search on Amazon
#
# [24 rows x 5847 columns]

# %%
placement_detail.groupby(placement_detail.placement_type).sum()
# Out:
#                                          id  placement  impressions  clicks  \
# placement_type
# First page Top of Search on Amazon  4608892   41210016       108655    3093
# Other Placements                     346548    3526938       152156     223
# Product pages on Amazon             5711113   52026436      3028248    3736
# Remarketing off-Amazon               150777    1024275        78994      92
# Rest of search on Amazon            5951333   51863055      1021963    3403
# Top of Search                        337317    3412210       148690    2249
#
#                                           CtR      CpC    spend        ACoS  \
# placement_type
# First page Top of Search on Amazon   0.000000   994.67  4301.34  161.085564
# Other Placements                     3.238378    88.30   111.99    2.105885
# Product pages on Amazon              0.000000  1650.17  6157.14  247.080030
# Remarketing off-Amazon               0.000000    10.29    38.81    0.440620
# Rest of search on Amazon             0.000000  1007.91  3974.47  206.498538
# Top of Search                       15.687654   376.91  1743.47   37.529048
#
#                                        RoAS     sales  ...  conversion_rate  \
# placement_type                                         ...
# First page Top of Search on Amazon  50.7900  18568.96  ...         0.000000
# Other Placements                    14.7507   1380.82  ...        27.999996
# Product pages on Amazon             15.8091   6735.95  ...         0.000000
# Remarketing off-Amazon               0.2459     30.72  ...         0.000000
# Rest of search on Amazon            31.5949   8282.33  ...         0.000000
# Top of Search                       31.4270  12331.69  ...       131.520536
#
#                                     page_views  NtB_orders  \
# placement_type
# First page Top of Search on Amazon         0.0         0.0
# Other Placements                         556.0        20.0
# Product pages on Amazon                    0.0         0.0
# Remarketing off-Amazon                     0.0         0.0
# Rest of search on Amazon                   0.0         0.0
# Top of Search                           6198.0       303.0
#
#                                     NtB_orders_percentage  NtB_sales  \
# placement_type
# First page Top of Search on Amazon               0.000000       0.00
# Other Placements                                14.333333     507.52
# Product pages on Amazon                          0.000000       0.00
# Remarketing off-Amazon                           0.000000       0.00
# Rest of search on Amazon                         0.000000       0.00
# Top of Search                                  142.588886    6279.04
#
#                                     NtB_sales_percentage  NtB_units  \
# placement_type
# First page Top of Search on Amazon              0.000000        0.0
# Other Placements                               13.889856       39.0
# Product pages on Amazon                         0.000000        0.0
# Remarketing off-Amazon                          0.000000        0.0
# Rest of search on Amazon                        0.000000        0.0
# Top of Search                                 139.436139      417.0
#
#                                     NtB_units_persentage  NtB_order_rate  \
# placement_type
# First page Top of Search on Amazon              0.000000        0.000000
# Other Placements                               14.300000       10.000000
# Product pages on Amazon                         0.000000        0.000000
# Remarketing off-Amazon                          0.000000        0.000000
# Rest of search on Amazon                        0.000000        0.000000
# Top of Search                                 141.065771       70.053414
#
#                                     campaign1
# placement_type
# First page Top of Search on Amazon    2138262
# Other Placements                        26107
# Product pages on Amazon               2633701
# Remarketing off-Amazon                1659165
# Rest of search on Amazon              2568089
# Top of Search                           25590
#
# [6 rows x 22 columns]

# %%
placement_detail.placement_type.unique()
# Out:
# array(['Top of Search', 'Other Placements', 'Product pages on Amazon',
#        'Rest of search on Amazon', 'First page Top of Search on Amazon',
#        'Remarketing off-Amazon'], dtype=object)

# %%
placement_detail.campaign1.unique()
# Out:
# array([   93,   100,   107,   114,    28,    14,     1,    21,    13,
#         1240, 52171,  1251,  1238,  1230,  1236, 52191,  1252,  1241,
#         1235,  1243,  1242,  1232,  1246,  1223,  1245,  1247,  1250,
#         1231,  1239,  1248,  1237,  1234,  1226, 52292, 52409,  1233,
#         1229,  1249,  1244, 55305, 55306])

# %%
camp1250 = placement_detail[placement_detail.campaign1 == 1250].sort_values(by = ['RoAS'], ascending = False)
camp1250.date.sort_values().unique()
# Out:
# array(['10/1/19', '10/2/19', '10/3/19', '10/4/19', '10/5/19', '7/28/19',
#        '7/30/19', '7/31/19', '8/1/19', '8/10/19', '8/11/19', '8/12/19',
#        '8/13/19', '8/14/19', '8/15/19', '8/16/19', '8/17/19', '8/18/19',
#        '8/19/19', '8/2/19', '8/20/19', '8/21/19', '8/22/19', '8/23/19',
#        '8/24/19', '8/25/19', '8/26/19', '8/27/19', '8/28/19', '8/29/19',
#        '8/3/19', '8/30/19', '8/31/19', '8/4/19', '8/5/19', '8/6/19',
#        '8/7/19', '8/8/19', '8/9/19', '9/1/19', '9/10/19', '9/11/19',
#        '9/12/19', '9/13/19', '9/14/19', '9/15/19', '9/16/19', '9/17/19',
#        '9/18/19', '9/19/19', '9/2/19', '9/20/19', '9/21/19', '9/22/19',
#        '9/23/19', '9/24/19', '9/25/19', '9/26/19', '9/27/19', '9/28/19',
#        '9/29/19', '9/3/19', '9/30/19', '9/4/19', '9/5/19', '9/6/19',
#        '9/7/19', '9/8/19', '9/9/19'], dtype=object)

# %%
camp1250[camp1250.date == '10/1/19'].T
# Out:
#                                           5623                      5802
# id                                        5626                      5805
# placement                                31077                     31198
# date                                   10/1/19                   10/1/19
# impressions                               1522                       195
# clicks                                       0                         0
# CtR                                        NaN                       NaN
# CpC                                        NaN                       NaN
# spend                                        0                         0
# ACoS                                       NaN                       NaN
# RoAS                                       NaN                       NaN
# sales                                        0                         0
# orders                                       0                         0
# units                                        0                         0
# conversion_rate                            NaN                       NaN
# page_views                                 NaN                       NaN
# NtB_orders                                 NaN                       NaN
# NtB_orders_percentage                      NaN                       NaN
# NtB_sales                                  NaN                       NaN
# NtB_sales_percentage                       NaN                       NaN
# NtB_units                                  NaN                       NaN
# NtB_units_persentage                       NaN                       NaN
# NtB_order_rate                             NaN                       NaN
# campaign1                                 1250                      1250
# placement_type         Product pages on Amazon  Rest of search on Amazon

# %%
camp1[camp1.placement == 31678]
# Out:
#                                                      2810  \
# id                                                   2813
# placement                                           31678
# date                                              8/21/19
# impressions                                             2
# clicks                                                  1
# CtR                                                   NaN
# CpC                                                  0.26
# spend                                                0.26
# ACoS                                             0.004051
# RoAS                                               2.4685
# sales                                               64.18
# orders                                                  2
# units                                                   4
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      3283  \
# id                                                   3286
# placement                                           31678
# date                                              8/30/19
# impressions                                             7
# clicks                                                  1
# CtR                                                   NaN
# CpC                                                  0.29
# spend                                                0.29
# ACoS                                             0.042336
# RoAS                                               0.2362
# sales                                                6.85
# orders                                                  1
# units                                                   1
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      5357  \
# id                                                   5360
# placement                                           31678
# date                                              9/25/19
# impressions                                            24
# clicks                                                  2
# CtR                                                   NaN
# CpC                                                  0.26
# spend                                                0.52
# ACoS                                             0.065245
# RoAS                                               0.1533
# sales                                                7.97
# orders                                                  1
# units                                                   1
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4330  \
# id                                                   4333
# placement                                           31678
# date                                              9/14/19
# impressions                                            47
# clicks                                                  1
# CtR                                                   NaN
# CpC                                                  0.68
# spend                                                0.68
# ACoS                                             0.085859
# RoAS                                               0.1165
# sales                                                7.92
# orders                                                  1
# units                                                   1
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4328  \
# id                                                   4331
# placement                                           31678
# date                                              9/12/19
# impressions                                            43
# clicks                                                  1
# CtR                                                   NaN
# CpC                                                  1.65
# spend                                                1.65
# ACoS                                              0.17134
# RoAS                                               0.0584
# sales                                                9.63
# orders                                                  2
# units                                                   2
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      2346  \
# id                                                   2349
# placement                                           31678
# date                                              8/16/19
# impressions                                            19
# clicks                                                  2
# CtR                                                   NaN
# CpC                                                  1.85
# spend                                                3.69
# ACoS                                              0.23384
# RoAS                                               0.0428
# sales                                               15.78
# orders                                                  2
# units                                                   2
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      3799  \
# id                                                   3802
# placement                                           31678
# date                                               9/4/19
# impressions                                            62
# clicks                                                  7
# CtR                                                   NaN
# CpC                                                  0.96
# spend                                                 6.7
# ACoS                                             0.289667
# RoAS                                               0.0345
# sales                                               23.13
# orders                                                  4
# units                                                   4
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      5355  \
# id                                                   5358
# placement                                           31678
# date                                              9/23/19
# impressions                                            48
# clicks                                                  2
# CtR                                                   NaN
# CpC                                                  1.53
# spend                                                3.05
# ACoS                                             0.382685
# RoAS                                               0.0261
# sales                                                7.97
# orders                                                  1
# units                                                   1
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      2344  \
# id                                                   2347
# placement                                           31678
# date                                              8/14/19
# impressions                                            17
# clicks                                                  2
# CtR                                                   NaN
# CpC                                                  1.15
# spend                                                 2.3
# ACoS                                             0.383973
# RoAS                                                0.026
# sales                                                5.99
# orders                                                  1
# units                                                   1
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4840  ...  \
# id                                                   4843  ...
# placement                                           31678  ...
# date                                              9/18/19  ...
# impressions                                            32  ...
# clicks                                                  2  ...
# CtR                                                   NaN  ...
# CpC                                                  1.61  ...
# spend                                                3.22  ...
# ACoS                                             0.406566  ...
# RoAS                                               0.0246  ...
# sales                                                7.92  ...
# orders                                                  1  ...
# units                                                   1  ...
# conversion_rate                                       NaN  ...
# page_views                                            NaN  ...
# NtB_orders                                            NaN  ...
# NtB_orders_percentage                                 NaN  ...
# NtB_sales                                             NaN  ...
# NtB_sales_percentage                                  NaN  ...
# NtB_units                                             NaN  ...
# NtB_units_persentage                                  NaN  ...
# NtB_order_rate                                        NaN  ...
# campaign1                                            1233  ...
# placement_type         First page Top of Search on Amazon  ...
#
#                                                      3800  \
# id                                                   3803
# placement                                           31678
# date                                               9/5/19
# impressions                                            42
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      3801  \
# id                                                   3804
# placement                                           31678
# date                                               9/6/19
# impressions                                            27
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      3802  \
# id                                                   3805
# placement                                           31678
# date                                               9/7/19
# impressions                                            43
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4324  \
# id                                                   4327
# placement                                           31678
# date                                               9/8/19
# impressions                                             2
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4326  \
# id                                                   4329
# placement                                           31678
# date                                              9/10/19
# impressions                                            17
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4839  \
# id                                                   4842
# placement                                           31678
# date                                              9/16/19
# impressions                                             0
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4842  \
# id                                                   4845
# placement                                           31678
# date                                              9/20/19
# impressions                                            36
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      4843  \
# id                                                   4846
# placement                                           31678
# date                                              9/21/19
# impressions                                            43
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      5354  \
# id                                                   5357
# placement                                           31678
# date                                              9/22/19
# impressions                                            37
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
#                                                      5358
# id                                                   5361
# placement                                           31678
# date                                              9/27/19
# impressions                                            17
# clicks                                                  0
# CtR                                                   NaN
# CpC                                                   NaN
# spend                                                   0
# ACoS                                                  NaN
# RoAS                                                  NaN
# sales                                                   0
# orders                                                  0
# units                                                   0
# conversion_rate                                       NaN
# page_views                                            NaN
# NtB_orders                                            NaN
# NtB_orders_percentage                                 NaN
# NtB_sales                                             NaN
# NtB_sales_percentage                                  NaN
# NtB_units                                             NaN
# NtB_units_persentage                                  NaN
# NtB_order_rate                                        NaN
# campaign1                                            1233
# placement_type         First page Top of Search on Amazon
#
# [24 rows x 43 columns]

# %%
camp1[camp1.placement == 31524].T
# Out:
#                                            5693                      2655  \
# id                                         5696                      2658
# placement                                 31524                     31524
# date                                    10/1/19                   8/19/19
# impressions                                 620                       187
# clicks                                        3                         1
# CtR                                         NaN                       NaN
# CpC                                        1.43                       1.5
# spend                                      4.28                       1.5
# ACoS                                   0.105967                  0.158061
# RoAS                                     0.0944                    0.0633
# sales                                     40.39                      9.49
# orders                                        2                         1
# units                                         3                         1
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            4151                      5697  \
# id                                         4154                      5700
# placement                                 31524                     31524
# date                                    9/12/19                   10/5/19
# impressions                                 773                       605
# clicks                                        7                         1
# CtR                                         NaN                       NaN
# CpC                                        1.42                      1.46
# spend                                      9.92                      1.46
# ACoS                                   0.158923                  0.183187
# RoAS                                     0.0629                    0.0546
# sales                                     62.42                      7.97
# orders                                        2                         1
# units                                         8                         1
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5174                      5176  \
# id                                         5177                      5179
# placement                                 31524                     31524
# date                                    9/24/19                   9/27/19
# impressions                                 610                       362
# clicks                                        5                         2
# CtR                                         NaN                       NaN
# CpC                                        1.37                      1.39
# spend                                      6.85                      2.77
# ACoS                                   0.286491                  0.291886
# RoAS                                     0.0349                    0.0343
# sales                                     23.91                      9.49
# orders                                        3                         1
# units                                         3                         1
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5177                      2654  \
# id                                         5180                      2657
# placement                                 31524                     31524
# date                                    9/28/19                   8/18/19
# impressions                                 310                       167
# clicks                                        2                         2
# CtR                                         NaN                       NaN
# CpC                                        1.37                      1.27
# spend                                      2.74                      2.54
# ACoS                                   0.343789                  0.363376
# RoAS                                     0.0291                    0.0275
# sales                                      7.97                      6.99
# orders                                        1                         1
# units                                         1                         1
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            4152                      5172  \
# id                                         4155                      5175
# placement                                 31524                     31524
# date                                    9/13/19                   9/22/19
# impressions                                 611                       794
# clicks                                        3                         6
# CtR                                         NaN                       NaN
# CpC                                        1.25                      1.15
# spend                                      3.75                      6.87
# ACoS                                   0.389408                  0.430991
# RoAS                                     0.0257                    0.0232
# sales                                      9.63                     15.94
# orders                                        2                         2
# units                                         2                         2
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                        ...                      2170  \
# id                     ...                      2173
# placement              ...                     31524
# date                   ...                   8/13/19
# impressions            ...                       181
# clicks                 ...                         0
# CtR                    ...                       NaN
# CpC                    ...                       NaN
# spend                  ...                         0
# ACoS                   ...                       NaN
# RoAS                   ...                       NaN
# sales                  ...                         0
# orders                 ...                         0
# units                  ...                         0
# conversion_rate        ...                       NaN
# page_views             ...                       NaN
# NtB_orders             ...                       NaN
# NtB_orders_percentage  ...                       NaN
# NtB_sales              ...                       NaN
# NtB_sales_percentage   ...                       NaN
# NtB_units              ...                       NaN
# NtB_units_persentage   ...                       NaN
# NtB_order_rate         ...                       NaN
# campaign1              ...                      1233
# placement_type         ...  Rest of search on Amazon
#
#                                            2172                      2173  \
# id                                         2175                      2176
# placement                                 31524                     31524
# date                                    8/15/19                   8/16/19
# impressions                                 223                       152
# clicks                                        0                         0
# CtR                                         NaN                       NaN
# CpC                                         NaN                       NaN
# spend                                         0                         0
# ACoS                                        NaN                       NaN
# RoAS                                        NaN                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            2174                      2657  \
# id                                         2177                      2660
# placement                                 31524                     31524
# date                                    8/17/19                   8/21/19
# impressions                                 157                        19
# clicks                                        0                         0
# CtR                                         NaN                       NaN
# CpC                                         NaN                       NaN
# spend                                         0                         0
# ACoS                                        NaN                       NaN
# RoAS                                        NaN                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            3119                      3123  \
# id                                         3122                      3126
# placement                                 31524                     31524
# date                                    8/26/19                   8/30/19
# impressions                                  30                       106
# clicks                                        0                         0
# CtR                                         NaN                       NaN
# CpC                                         NaN                       NaN
# spend                                         0                         0
# ACoS                                        NaN                       NaN
# RoAS                                        NaN                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            3626                      4147  \
# id                                         3629                      4150
# placement                                 31524                     31524
# date                                     9/7/19                    9/8/19
# impressions                                 424                        17
# clicks                                        0                         0
# CtR                                         NaN                       NaN
# CpC                                         NaN                       NaN
# spend                                         0                         0
# ACoS                                        NaN                       NaN
# RoAS                                        NaN                       NaN
# sales                                         0                         0
# orders                                        0                         0
# units                                         0                         0
# conversion_rate                             NaN                       NaN
# page_views                                  NaN                       NaN
# NtB_orders                                  NaN                       NaN
# NtB_orders_percentage                       NaN                       NaN
# NtB_sales                                   NaN                       NaN
# NtB_sales_percentage                        NaN                       NaN
# NtB_units                                   NaN                       NaN
# NtB_units_persentage                        NaN                       NaN
# NtB_order_rate                              NaN                       NaN
# campaign1                                  1233                      1233
# placement_type         Rest of search on Amazon  Rest of search on Amazon
#
#                                            5696
# id                                         5699
# placement                                 31524
# date                                    10/4/19
# impressions                                 736
# clicks                                        0
# CtR                                         NaN
# CpC                                         NaN
# spend                                         0
# ACoS                                        NaN
# RoAS                                        NaN
# sales                                         0
# orders                                        0
# units                                         0
# conversion_rate                             NaN
# page_views                                  NaN
# NtB_orders                                  NaN
# NtB_orders_percentage                       NaN
# NtB_sales                                   NaN
# NtB_sales_percentage                        NaN
# NtB_units                                   NaN
# NtB_units_persentage                        NaN
# NtB_order_rate                              NaN
# campaign1                                  1233
# placement_type         Rest of search on Amazon
#
# [24 rows x 49 columns]
